# %%
import pandas
import numpy
import sklearn
import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize']=10,8
from sklearn import datasets,linear_model
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cancer_data=pandas.read_csv('C:/Users/PG VINEETHA/Downloads/Cancer.csv')

# %%
cancer_data
# Out:
#                    class  age menopause  tumor-size  inv-nodes node-caps  \
# 0   no-recurrence-events   12      it40           2          1       yes
# 1     reccurrence-events   25      ge40           8          4        no
# 2     reccurrence-events   38  premeno.          12          7        no
# 3   no-recurrence-events   44      it40          18         10        no
# 4   no-recurrence-events   52  premeno.          24         13       yes
# 5   no-recurrence-events   64  premeno.          29         16       yes
# 6     reccurrence-events   78      ge40          34         19        no
# 7     reccurrence-events   81      it40          36         22        no
# 8   no-recurrence-events   92      ge40          42         26       yes
# 9     reccurrence-events   46      it40          47         28       yes
# 10  no-recurrence-events    7  premeno.          51         31        no
# 11  no-recurrence-events   32  premeno.          58         34       yes
# ...

# %%
cancer_data_X=cancer_data[['age','menopause','tumor-size','inv-nodes','node-caps','deg-malig','breast','brease-quad']]
cancer_data_Y=cancer_data[['irradiat']]

# %%
cancer_data_X
# Out:
#     age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 0    12      it40           2          1       yes          1   left
# 1    25      ge40           8          4        no          3   left
# 2    38  premeno.          12          7        no          2  right
# 3    44      it40          18         10        no          2   left
# 4    52  premeno.          24         13       yes          3  right
# 5    64  premeno.          29         16       yes          1  right
# 6    78      ge40          34         19        no          1  right
# 7    81      it40          36         22        no          2   left
# 8    92      ge40          42         26       yes          2   left
# 9    46      it40          47         28       yes          3  right
# 10    7  premeno.          51         31        no          2  right
# 11   32  premeno.          58         34       yes          1   left
# 12   46      it40          64         38       yes          2   left
# ...

# %%
cancer_data_Y
# Out:
#    irradiat
# 0        no
# 1       yes
# 2       yes
# 3        no
# 4        no
# 5        no
# 6       yes
# 7        no
# 8       yes
# 9       yes
# 10       no
# 11       no
# 12      yes
# 13      yes

# %%
X_train,X_test,Y_train,Y_test=train_test_split(cancer_data_X,cancer_data_Y,test_size=0.18)

# %%
X_train
# Out:
#     age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2    38  premeno.          12          7        no          2  right
# 11   32  premeno.          58         34       yes          1   left
# 8    92      ge40          42         26       yes          2   left
# 5    64  premeno.          29         16       yes          1  right
# 7    81      it40          36         22        no          2   left
# 13   17      ge40          67         39        no          3  right
# 3    44      it40          18         10        no          2   left
# 12   46      it40          64         38       yes          2   left
# 4    52  premeno.          24         13       yes          3  right
# 1    25      ge40           8          4        no          3   left
# 9    46      it40          47         28       yes          3  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# 5    right-low
# 7     right-up
# 13   right-low
# 3     right-up
# ...

# %%
age_scaler=StandardScaler()
age_scaler.fit(pandas.DataFrame(X_train['age']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train[['age']]=age_scaler.transform(X_train[['age']])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2  -0.499506  premeno.          12          7        no          2  right
# 11 -0.776544  premeno.          58         34       yes          1   left
# 8   1.993828      ge40          42         26       yes          2   left
# 5   0.700988  premeno.          29         16       yes          1  right
# 7   1.485927      it40          36         22        no          2   left
# 13 -1.469137      ge40          67         39        no          3  right
# 3  -0.222469      it40          18         10        no          2   left
# 12 -0.130124      it40          64         38       yes          2   left
# 4   0.146914  premeno.          24         13       yes          3  right
# 1  -1.099754      ge40           8          4        no          3   left
# 9  -0.130124      it40          47         28       yes          3  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
tumor_scaler=StandardScaler()
tumor_scaler.fit(pandas.DataFrame(X_train['tumor-size']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train[['tumor-size']]=tumor_scaler.transform(X_train[['tumor-size']])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2  -0.499506  premeno.   -1.261781          7        no          2  right
# 11 -0.776544  premeno.    1.076905         34       yes          1   left
# 8   1.993828      ge40    0.263449         26       yes          2   left
# 5   0.700988  premeno.   -0.397484         16       yes          1  right
# 7   1.485927      it40   -0.041597         22        no          2   left
# 13 -1.469137      ge40    1.534474         39        no          3  right
# 3  -0.222469      it40   -0.956735         10        no          2   left
# 12 -0.130124      it40    1.381951         38       yes          2   left
# 4   0.146914  premeno.   -0.651689         13       yes          3  right
# 1  -1.099754      ge40   -1.465145          4        no          3   left
# 9  -0.130124      it40    0.517654         28       yes          3  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
inv_scaler=StandardScaler()
inv_scaler.fit(pandas.DataFrame(X_train['inv-nodes']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train[['inv-nodes']]=inv_scaler.transform(X_train[['inv-nodes']])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847        no          2  right
# 11 -0.776544  premeno.    1.076905   1.049631       yes          1   left
# 8   1.993828      ge40    0.263449   0.375416       yes          2   left
# 5   0.700988  premeno.   -0.397484  -0.467354       yes          1  right
# 7   1.485927      it40   -0.041597   0.038308        no          2   left
# 13 -1.469137      ge40    1.534474   1.471016        no          3  right
# 3  -0.222469      it40   -0.956735  -0.973016        no          2   left
# 12 -0.130124      it40    1.381951   1.386739       yes          2   left
# 4   0.146914  premeno.   -0.651689  -0.720185       yes          3  right
# 1  -1.099754      ge40   -1.465145  -1.478678        no          3   left
# 9  -0.130124      it40    0.517654   0.543969       yes          3  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
deg_scaler=StandardScaler()
deg_scaler.fit(pandas.DataFrame(X_train['deg-malig']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train[['deg-malig']]=deg_scaler.transform(X_train[['deg-malig']])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847        no  -0.254000  right
# 11 -0.776544  premeno.    1.076905   1.049631       yes  -1.651002   left
# 8   1.993828      ge40    0.263449   0.375416       yes  -0.254000   left
# 5   0.700988  premeno.   -0.397484  -0.467354       yes  -1.651002  right
# 7   1.485927      it40   -0.041597   0.038308        no  -0.254000   left
# 13 -1.469137      ge40    1.534474   1.471016        no   1.143001  right
# 3  -0.222469      it40   -0.956735  -0.973016        no  -0.254000   left
# 12 -0.130124      it40    1.381951   1.386739       yes  -0.254000   left
# 4   0.146914  premeno.   -0.651689  -0.720185       yes   1.143001  right
# 1  -1.099754      ge40   -1.465145  -1.478678        no   1.143001   left
# 9  -0.130124      it40    0.517654   0.543969       yes   1.143001  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847        no  -0.254000  right
# 11 -0.776544  premeno.    1.076905   1.049631       yes  -1.651002   left
# 8   1.993828      ge40    0.263449   0.375416       yes  -0.254000   left
# 5   0.700988  premeno.   -0.397484  -0.467354       yes  -1.651002  right
# 7   1.485927      it40   -0.041597   0.038308        no  -0.254000   left
# 13 -1.469137      ge40    1.534474   1.471016        no   1.143001  right
# 3  -0.222469      it40   -0.956735  -0.973016        no  -0.254000   left
# 12 -0.130124      it40    1.381951   1.386739       yes  -0.254000   left
# 4   0.146914  premeno.   -0.651689  -0.720185       yes   1.143001  right
# 1  -1.099754      ge40   -1.465145  -1.478678        no   1.143001   left
# 9  -0.130124      it40    0.517654   0.543969       yes   1.143001  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
node_encoder=preprocessing.LabelEncoder()
node_encoder.fit(pandas.DataFrame(X_train['node-caps']))
X_train[['node-caps']]=node_encoder.transform(X_train['node-caps'])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes  node-caps  deg-malig breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847          0  -0.254000  right
# 11 -0.776544  premeno.    1.076905   1.049631          1  -1.651002   left
# 8   1.993828      ge40    0.263449   0.375416          1  -0.254000   left
# 5   0.700988  premeno.   -0.397484  -0.467354          1  -1.651002  right
# 7   1.485927      it40   -0.041597   0.038308          0  -0.254000   left
# 13 -1.469137      ge40    1.534474   1.471016          0   1.143001  right
# 3  -0.222469      it40   -0.956735  -0.973016          0  -0.254000   left
# 12 -0.130124      it40    1.381951   1.386739          1  -0.254000   left
# 4   0.146914  premeno.   -0.651689  -0.720185          1   1.143001  right
# 1  -1.099754      ge40   -1.465145  -1.478678          0   1.143001   left
# 9  -0.130124      it40    0.517654   0.543969          1   1.143001  right
#
#    brease-quad
# 2      central
# 11     central
# 8     left-low
# ...

# %%
breast_encoder=preprocessing.LabelEncoder()
breast_encoder.fit(pandas.DataFrame(X_train['breast']))
X_train[['breast']]=breast_encoder.transform(X_train['breast'])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544  premeno.    1.076905   1.049631          1  -1.651002       0
# 8   1.993828      ge40    0.263449   0.375416          1  -0.254000       0
# 5   0.700988  premeno.   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927      it40   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137      ge40    1.534474   1.471016          0   1.143001       1
# 3  -0.222469      it40   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124      it40    1.381951   1.386739          1  -0.254000       0
# 4   0.146914  premeno.   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754      ge40   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124      it40    0.517654   0.543969          1   1.143001       1
#
#    brease-quad
# 2      central
# 11     central
# ...

# %%
brease_encoder=preprocessing.LabelEncoder()
brease_encoder.fit(pandas.DataFrame(X_train['brease-quad']))
X_train[['brease-quad']]=brease_encoder.transform(X_train['brease-quad'])

# %%
X_train
# Out:
#          age menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506  premeno.   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544  premeno.    1.076905   1.049631          1  -1.651002       0
# 8   1.993828      ge40    0.263449   0.375416          1  -0.254000       0
# 5   0.700988  premeno.   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927      it40   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137      ge40    1.534474   1.471016          0   1.143001       1
# 3  -0.222469      it40   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124      it40    1.381951   1.386739          1  -0.254000       0
# 4   0.146914  premeno.   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754      ge40   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124      it40    0.517654   0.543969          1   1.143001       1
#
#     brease-quad
# 2             0
# 11            0
# ...

# %%
meno_encoder=preprocessing.LabelEncoder()
meno_encoder.fit(pandas.DataFrame(X_train['menopause']))
X_train[['menopause']]=meno_encoder.transform(X_train['menopause'])

# %%
X_train
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506          2   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544          2    1.076905   1.049631          1  -1.651002       0
# 8   1.993828          0    0.263449   0.375416          1  -0.254000       0
# 5   0.700988          2   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927          1   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137          0    1.534474   1.471016          0   1.143001       1
# 3  -0.222469          1   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124          1    1.381951   1.386739          1  -0.254000       0
# 4   0.146914          2   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754          0   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124          1    0.517654   0.543969          1   1.143001       1
#
#     brease-quad
# 2             0
# ...

# %%
brease_scaler=StandardScaler()
brease_scaler.fit(pandas.DataFrame(X_train['brease-quad']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train[['brease-quad']]=brease_scaler.transform(X_train[['brease-quad']])

# %%
X_train
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506          2   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544          2    1.076905   1.049631          1  -1.651002       0
# 8   1.993828          0    0.263449   0.375416          1  -0.254000       0
# 5   0.700988          2   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927          1   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137          0    1.534474   1.471016          0   1.143001       1
# 3  -0.222469          1   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124          1    1.381951   1.386739          1  -0.254000       0
# 4   0.146914          2   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754          0   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124          1    0.517654   0.543969          1   1.143001       1
#
#     brease-quad
# 2     -1.521217
# ...

# %%
Y_train
# Out:
#    irradiat
# 2       yes
# 11       no
# 8       yes
# 5        no
# 7        no
# 13      yes
# 3        no
# 12      yes
# 4        no
# 1       yes
# 9       yes

# %%
Y_train['irradiat']=Y_train['irradiat'].map({'yes':1,'no':0})

# %%
Y_test['irradiat']=Y_test['irradiat'].map({'yes':1,'no':0})

# %%
Y_test
# Out:
#     irradiat
# 6          1
# 10         0
# 0          0

# %%
Y_train
# Out:
#     irradiat
# 2          1
# 11         0
# 8          1
# 5          0
# 7          0
# 13         1
# 3          0
# 12         1
# 4          0
# 1          1
# 9          1

# %%
X_train
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506          2   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544          2    1.076905   1.049631          1  -1.651002       0
# 8   1.993828          0    0.263449   0.375416          1  -0.254000       0
# 5   0.700988          2   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927          1   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137          0    1.534474   1.471016          0   1.143001       1
# 3  -0.222469          1   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124          1    1.381951   1.386739          1  -0.254000       0
# 4   0.146914          2   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754          0   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124          1    0.517654   0.543969          1   1.143001       1
#
#     brease-quad
# 2     -1.521217
# ...

# %%
X_train['menopause'].groupby(X_train['age']).std()
# Out:
# age
# -1.469137    NaN
# -1.099754    NaN
# -0.776544    NaN
# -0.499506    NaN
# -0.222469    NaN
# -0.130124    0.0
#  0.146914    NaN
#  0.700988    NaN
#  1.485927    NaN
#  1.993828    NaN
# Name: menopause, dtype: float64

# %%
X_train
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 2  -0.499506          2   -1.261781  -1.225847          0  -0.254000       1
# 11 -0.776544          2    1.076905   1.049631          1  -1.651002       0
# 8   1.993828          0    0.263449   0.375416          1  -0.254000       0
# 5   0.700988          2   -0.397484  -0.467354          1  -1.651002       1
# 7   1.485927          1   -0.041597   0.038308          0  -0.254000       0
# 13 -1.469137          0    1.534474   1.471016          0   1.143001       1
# 3  -0.222469          1   -0.956735  -0.973016          0  -0.254000       0
# 12 -0.130124          1    1.381951   1.386739          1  -0.254000       0
# 4   0.146914          2   -0.651689  -0.720185          1   1.143001       1
# 1  -1.099754          0   -1.465145  -1.478678          0   1.143001       0
# 9  -0.130124          1    0.517654   0.543969          1   1.143001       1
#
#     brease-quad
# 2     -1.521217
# ...

# %%
X_train_original=X_train
X_train=X_train.values
Y_train=Y_train.values

# %%
logistic_regression=LogisticRegression()

# %%
logistic_regression.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
X_test
# Out:
#     age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 6    78      ge40          34         19        no          1  right
# 10    7  premeno.          51         31        no          2  right
# 0    12      it40           2          1       yes          1   left
#
#    brease-quad
# 6      central
# 10     central
# 0      left-up

# %%
X_test
# Out:
#     age menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 6    78      ge40          34         19        no          1  right
# 10    7  premeno.          51         31        no          2  right
# 0    12      it40           2          1       yes          1   left
#
#    brease-quad
# 6      central
# 10     central
# 0      left-up

# %%
meno_encoder=preprocessing.LabelEncoder()
meno_encoder.fit(pandas.DataFrame(X_test['menopause']))
X_test[['menopause']]=meno_encoder.transform(X_test['menopause'])

# %%
X_test
# Out:
#     age  menopause  tumor-size  inv-nodes node-caps  deg-malig breast  \
# 6    78          0          34         19        no          1  right
# 10    7          2          51         31        no          2  right
# 0    12          1           2          1       yes          1   left
#
#    brease-quad
# 6      central
# 10     central
# 0      left-up

# %%
node_encoder=preprocessing.LabelEncoder()
node_encoder.fit(pandas.DataFrame(X_test['node-caps']))
X_test[['node-caps']]=node_encoder.transform(X_test['node-caps'])

# %%
X_test
# Out:
#     age  menopause  tumor-size  inv-nodes  node-caps  deg-malig breast  \
# 6    78          0          34         19          0          1  right
# 10    7          2          51         31          0          2  right
# 0    12          1           2          1          1          1   left
#
#    brease-quad
# 6      central
# 10     central
# 0      left-up

# %%
breast_encoder=preprocessing.LabelEncoder()
breast_encoder.fit(pandas.DataFrame(X_test['breast']))
X_test[['breast']]=breast_encoder.transform(X_test['breast'])

# %%
X_test
# Out:
#     age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6    78          0          34         19          0          1       1
# 10    7          2          51         31          0          2       1
# 0    12          1           2          1          1          1       0
#
#    brease-quad
# 6      central
# 10     central
# 0      left-up

# %%
brease_encoder=preprocessing.LabelEncoder()
brease_encoder.fit(pandas.DataFrame(X_test['brease-quad']))
X_test[['brease-quad']]=brease_encoder.transform(X_test['brease-quad'])

# %%
X_test
# Out:
#     age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6    78          0          34         19          0          1       1
# 10    7          2          51         31          0          2       1
# 0    12          1           2          1          1          1       0
#
#     brease-quad
# 6             0
# 10            0
# 0             1

# %%
age_scaler=StandardScaler()
age_scaler.fit(pandas.DataFrame(X_test['age']))
X_test[['age']]=age_scaler.transform(X_test[['age']])

# %%
X_test
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6   1.411396          0          34         19          0          1       1
# 10 -0.782964          2          51         31          0          2       1
# 0  -0.628432          1           2          1          1          1       0
#
#     brease-quad
# 6             0
# 10            0
# 0             1

# %%
tumor_scaler=StandardScaler()
tumor_scaler.fit(pandas.DataFrame(X_test['tumor-size']))
X_test[['tumor-size']]=tumor_scaler.transform(X_test[['tumor-size']])

# %%
X_test
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6   1.411396          0    0.246133         19          0          1       1
# 10 -0.782964          2    1.082986         31          0          2       1
# 0  -0.628432          1   -1.329120          1          1          1       0
#
#     brease-quad
# 6             0
# 10            0
# 0             1

# %%
inv_scaler=StandardScaler()
inv_scaler.fit(pandas.DataFrame(X_test['inv-nodes']))
X_test[['inv-nodes']]=inv_scaler.transform(X_test[['inv-nodes']])

# %%
X_test
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6   1.411396          0    0.246133   0.162221          0          1       1
# 10 -0.782964          2    1.082986   1.135550          0          2       1
# 0  -0.628432          1   -1.329120  -1.297771          1          1       0
#
#     brease-quad
# 6             0
# 10            0
# 0             1

# %%
deg_scaler=StandardScaler()
deg_scaler.fit(pandas.DataFrame(X_test['deg-malig']))
X_test[['deg-malig']]=deg_scaler.transform(X_test[['deg-malig']])

# %%
X_test
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6   1.411396          0    0.246133   0.162221          0  -0.707107       1
# 10 -0.782964          2    1.082986   1.135550          0   1.414214       1
# 0  -0.628432          1   -1.329120  -1.297771          1  -0.707107       0
#
#     brease-quad
# 6             0
# 10            0
# 0             1

# %%
brease_scaler=StandardScaler()
brease_scaler.fit(pandas.DataFrame(X_test['brease-quad']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_test[['brease-quad']]=brease_scaler.transform(X_test[['brease-quad']])

# %%
X_test
# Out:
#          age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 6   1.411396          0    0.246133   0.162221          0  -0.707107       1
# 10 -0.782964          2    1.082986   1.135550          0   1.414214       1
# 0  -0.628432          1   -1.329120  -1.297771          1  -0.707107       0
#
#     brease-quad
# 6     -0.707107
# 10    -0.707107
# 0      1.414214

# %%
Y_pred=logistic_regression.predict(X_test)

# %%
Y_pred
# Out:
# array([1, 1, 0], dtype=int64)

# %%
print('R2 Score; %.2f' % r2_score(Y_test,Y_pred))
# Out:
# R2 Score; -0.50

# %%
print("Mean squared error:%.1f" % mean_squared_error(Y_test,Y_pred))
# Out:
# Mean squared error:0.3

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666

# %% [markdown]
# # DECISION TREE

# %%
from sklearn import tree

# %%
decision_tree=tree.DecisionTreeClassifier()

# %%
decision_tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
Y_pred=decision_tree.predict(X_test)
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666

# %%
Y_pred
# Out:
# array([1, 1, 0], dtype=int64)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666

# %% [markdown]
# # BAYE'S THEOREM

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_bayes=GaussianNB()
naive_bayes.fit(X_train,Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred=naive_bayes.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest=RandomForestClassifier()
random_forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Y_pred=random_forest.predict(X_test)
Y_pred_prob=random_forest.predict_proba(X_test)
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666

# %%
Y_pred=random_forest.predict(X_test)

# %%
Y_pred_prob=random_forest.predict_proba(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.6666666666666666
